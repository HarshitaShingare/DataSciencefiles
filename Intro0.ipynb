# %%
10+20
# Out:
# 30

# %%
#sinle line comment
"""
multiple
 line
 comment
"""
# Out:
# ' \nmultiple\n line\n comment\n'

# %%
13//2
# Out:
# 6

# %%
"hello"
# Out:
# 'hello'

# %%
print("welcome to ExcelR")
# Out:
# welcome to ExcelR

# %%
'hello'
# Out:
# 'hello'

# %%
120/12*2-4
# Out:
# 16.0

# %%
marks=100
marks
# Out:
# 100

# %%
type(marks)
# Out:
# int

# %% [markdown]
# Boolean Operations

# %%
x=True
y=False

# %%
x or y
# Out:
# True

# %%
x and y
# Out:
# False

# %%
not x
# Out:
# False

# %%
x = 13
y = 5

# %%
c1 = x>y
c1
# Out:
# True

# %%
c2 = x<y
c2
# Out:
# False

# %%
not c1
# Out:
# False

# %%
not c2
# Out:
# True

# %%
type(c1)
# Out:
# bool

# %%
price=50.5
price
type(price) #by default only get the output of last command
# Out:
# float

# %%
print(price) #to see intermediate line"s output use print function
type(price)
# Out:
# 50.5
# float

# %%
name= "harshita"
type(name)
# Out:
# str

# %%
dir(str) #all the methods that can be applied on the strings
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
str1="welcome to data sceince"
str1.capitalize()
# Out:
# 'Welcome to data sceince'

# %%
str1
# Out:
# 'welcome to data sceince'

# %%
str1.upper()
# Out:
# 'WELCOME TO DATA SCEINCE'

# %%
str1.lower()
# Out:
# 'welcome to data sceince'

# %%
str1.title()
# Out:
# 'Welcome To Data Sceince'

# %%
food="BrIYanI"
name="haRsHitA"
print(food.swapcase(), name.swapcase())
# Out:
# bRiyANi HArShITa

# %%
s1="My name is Harshita."
s1.split() #list of strings is created
# Out:
# ['My', 'name', 'is', 'Harshita.']

# %%
s2="Mumbai-Pune-Mumbai" #delimiter is space
s2.split()
# Out:
# ['Mumbai-Pune-Mumbai']

# %%
s2.split("-") #dekimeter is made "-"
# Out:
# ['Mumbai', 'Pune', 'Mumbai']

# %%
mail="harshita@excelr.com"
mail.split("@")
# Out:
# ['harshita', 'excelr.com']

# %%
s1
# Out:
# 'My name is Harshita.'

# %%
s1.replace("Harshita","jyoti")
# Out:
# 'My name is jyoti.'

# %%
s1
# Out:
# 'My name is Harshita.'

# %%
city="satara"
city.count("a")
# Out:
# 3

# %%
"Harshita".count("H")
# Out:
# 1
